# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\HP\\Desktop\\Pandas\\Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.shape
# Out:
# (150, 6)

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df[['Id', 'SepalLengthCm', 'SepalWidthCm']]
# Out:
#       Id  SepalLengthCm  SepalWidthCm
# 0      1            5.1           3.5
# 1      2            4.9           3.0
# 2      3            4.7           3.2
# 3      4            4.6           3.1
# 4      5            5.0           3.6
# ..   ...            ...           ...
# 145  146            6.7           3.0
# 146  147            6.3           2.5
# 147  148            6.5           3.0
# 148  149            6.2           3.4
# 149  150            5.9           3.0
#
# [150 rows x 3 columns]

# %%
df.loc[0:4]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.loc[0:4:2]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.iloc[0:4]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa

# %%
df.iloc[0:4,0:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm
# 0   1            5.1           3.5
# 1   2            4.9           3.0
# 2   3            4.7           3.2
# 3   4            4.6           3.1

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
obj = df.groupby('Species')

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
obj.get_group('Iris-versicolor')
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50   51            7.0           3.2            4.7           1.4
# 51   52            6.4           3.2            4.5           1.5
# 52   53            6.9           3.1            4.9           1.5
# 53   54            5.5           2.3            4.0           1.3
# 54   55            6.5           2.8            4.6           1.5
# 55   56            5.7           2.8            4.5           1.3
# 56   57            6.3           3.3            4.7           1.6
# 57   58            4.9           2.4            3.3           1.0
# 58   59            6.6           2.9            4.6           1.3
# 59   60            5.2           2.7            3.9           1.4
# 60   61            5.0           2.0            3.5           1.0
# 61   62            5.9           3.0            4.2           1.5
# 62   63            6.0           2.2            4.0           1.0
# ...

# %%
obj.describe()
# Out:
#                    Id                                                        \
#                 count   mean       std    min     25%    50%     75%    max
# Species
# Iris-setosa      50.0   25.5  14.57738    1.0   13.25   25.5   37.75   50.0
# Iris-versicolor  50.0   75.5  14.57738   51.0   63.25   75.5   87.75  100.0
# Iris-virginica   50.0  125.5  14.57738  101.0  113.25  125.5  137.75  150.0
#
#                 SepalLengthCm         ... PetalLengthCm      PetalWidthCm  \
#                         count   mean  ...           75%  max        count
# Species                               ...
# Iris-setosa              50.0  5.006  ...         1.575  1.9         50.0
# Iris-versicolor          50.0  5.936  ...         4.600  5.1         50.0
# Iris-virginica           50.0  6.588  ...         5.875  6.9         50.0
#
#
#                   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa      0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# ...

# %%
df.rename({'Species':'Target'},axis=1,inplace=True)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Target
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df['new_col'] = df['SepalWidthCm']*5

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Target  new_col
# 0       Iris-setosa     17.5
# 1       Iris-setosa     15.0
# 2       Iris-setosa     16.0
# 3       Iris-setosa     15.5
# ...

# %%
df.drop_duplicates()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Target  new_col
# 0       Iris-setosa     17.5
# 1       Iris-setosa     15.0
# 2       Iris-setosa     16.0
# 3       Iris-setosa     15.5
# ...

# %%
df.drop('new_col',axis=1, inplace=True)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Target
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df[df['SepalWidthCm'] == df['SepalWidthCm'].max()]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm       Target
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa

# %%
df[df['SepalWidthCm'] == df['SepalWidthCm'].min()]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 60  61            5.0           2.0            3.5           1.0
#
#              Target
# 60  Iris-versicolor

# %%
p = [{'a':1,'b':2,'c':3},{'a':11,'b':21,'c':31},{'a':12,'b':22,'c':32}]
a = pd.DataFrame(p)
a
# Out:
#     a   b   c
# 0   1   2   3
# 1  11  21  31
# 2  12  22  32

# %%
q = [{'a':111, 'b':112, 'c':113}, {'a':221, 'b':222, 'c':223}, {'a':331, 'b':332, 'c':333}]
b = pd.DataFrame(q)
b
# Out:
#      a    b    c
# 0  111  112  113
# 1  221  222  223
# 2  331  332  333

# %%
c = pd.concat([a,b])

# %%
c
# Out:
#      a    b    c
# 0    1    2    3
# 1   11   21   31
# 2   12   22   32
# 0  111  112  113
# 1  221  222  223
# 2  331  332  333

# %%
c = pd.concat([a,b],axis=1)
c
# Out:
#     a   b   c    a    b    c
# 0   1   2   3  111  112  113
# 1  11  21  31  221  222  223
# 2  12  22  32  331  332  333

# %%
c = pd.concat([a,b],keys=('x','y'))
c
# Out:
#        a    b    c
# x 0    1    2    3
#   1   11   21   31
#   2   12   22   32
# y 0  111  112  113
#   1  221  222  223
#   2  331  332  333

# %%
c = pd.concat([a,b],axis=1,keys=('x','y'))
c
# Out:
#     x            y
#     a   b   c    a    b    c
# 0   1   2   3  111  112  113
# 1  11  21  31  221  222  223
# 2  12  22  32  331  332  333

# %%
c.loc[:,'x']
# Out:
#     a   b   c
# 0   1   2   3
# 1  11  21  31
# 2  12  22  32

# %%
c.loc[:,'y']
# Out:
#      a    b    c
# 0  111  112  113
# 1  221  222  223
# 2  331  332  333

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.reset_index()
# Out:
#      index   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0        0    1            5.1           3.5            1.4           0.2
# 1        1    2            4.9           3.0            1.4           0.2
# 2        2    3            4.7           3.2            1.3           0.2
# 3        3    4            4.6           3.1            1.5           0.2
# 4        4    5            5.0           3.6            1.4           0.2
# ..     ...  ...            ...           ...            ...           ...
# 145    145  146            6.7           3.0            5.2           2.3
# 146    146  147            6.3           2.5            5.0           1.9
# 147    147  148            6.5           3.0            5.2           2.0
# 148    148  149            6.2           3.4            5.4           2.3
# 149    149  150            5.9           3.0            5.1           1.8
#
#              Target
# 0       Iris-setosa
# 1       Iris-setosa
# ...

# %%
df.set_index('Target')
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Target
# Iris-setosa       1            5.1           3.5            1.4           0.2
# Iris-setosa       2            4.9           3.0            1.4           0.2
# Iris-setosa       3            4.7           3.2            1.3           0.2
# Iris-setosa       4            4.6           3.1            1.5           0.2
# Iris-setosa       5            5.0           3.6            1.4           0.2
# ...             ...            ...           ...            ...           ...
# Iris-virginica  146            6.7           3.0            5.2           2.3
# Iris-virginica  147            6.3           2.5            5.0           1.9
# Iris-virginica  148            6.5           3.0            5.2           2.0
# Iris-virginica  149            6.2           3.4            5.4           2.3
# Iris-virginica  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
x = {
    'name':['Arun','jon','kat','Ak','Bob'],
    "age":['23 yr','25 yr','24','24 yr','21 yr'],
    'gen':['M','M','F','M','M'],
    'DOB':['12/4/1990','23/3/1997','21/5/1899','3/5/1988','9/12/1995']
}
df1 = pd.DataFrame(x)
df1
# Out:
#    name    age gen        DOB
# 0  Arun  23 yr   M  12/4/1990
# 1   jon  25 yr   M  23/3/1997
# 2   kat     24   F  21/5/1899
# 3    Ak  24 yr   M   3/5/1988
# 4   Bob  21 yr   M  9/12/1995

# %%
df1['gen_n'] = df1['gen'].map({'M':1,'F':0})

# %%
df1
# Out:
#    name    age gen        DOB  gen_n
# 0  Arun  23 yr   M  12/4/1990      1
# 1   jon  25 yr   M  23/3/1997      1
# 2   kat     24   F  21/5/1899      0
# 3    Ak  24 yr   M   3/5/1988      1
# 4   Bob  21 yr   M  9/12/1995      1

# %%
df2 = pd.DataFrame({
    'id':[1,2,3,4],
    'employee':['Akshay','Swapnil','Nikhil','Sonali'],
    'sal':[60000,50000,55000,40000]
})
df2
# Out:
#    id employee    sal
# 0   1   Akshay  60000
# 1   2  Swapnil  50000
# 2   3   Nikhil  55000
# 3   4   Sonali  40000

# %%
df3 = pd.DataFrame({
    'id':[3,4,5,6],
    'department':['IT','HR','AC','Dev'],
    'bonus':[48000,52000,50000,58000]
})
df3
# Out:
#    id department  bonus
# 0   3         IT  48000
# 1   4         HR  52000
# 2   5         AC  50000
# 3   6        Dev  58000

# %%
pd.merge(df2,df3,on='id')
# Out:
#    id employee    sal department  bonus
# 0   3   Nikhil  55000         IT  48000
# 1   4   Sonali  40000         HR  52000

# %%
pd.merge(df2,df3,on='id',how = 'left')
# Out:
#    id employee    sal department    bonus
# 0   1   Akshay  60000        NaN      NaN
# 1   2  Swapnil  50000        NaN      NaN
# 2   3   Nikhil  55000         IT  48000.0
# 3   4   Sonali  40000         HR  52000.0

# %%
pd.merge(df2,df3,on='id',how='right')
# Out:
#    id employee      sal department  bonus
# 0   3   Nikhil  55000.0         IT  48000
# 1   4   Sonali  40000.0         HR  52000
# 2   5      NaN      NaN         AC  50000
# 3   6      NaN      NaN        Dev  58000

# %%
pd.merge(df2,df3,on='id',how='outer')
# Out:
#    id employee      sal department    bonus
# 0   1   Akshay  60000.0        NaN      NaN
# 1   2  Swapnil  50000.0        NaN      NaN
# 2   3   Nikhil  55000.0         IT  48000.0
# 3   4   Sonali  40000.0         HR  52000.0
# 4   5      NaN      NaN         AC  50000.0
# 5   6      NaN      NaN        Dev  58000.0

# %%
pd.concat([df2,df3])
# Out:
#    id employee      sal department    bonus
# 0   1   Akshay  60000.0        NaN      NaN
# 1   2  Swapnil  50000.0        NaN      NaN
# 2   3   Nikhil  55000.0        NaN      NaN
# 3   4   Sonali  40000.0        NaN      NaN
# 0   3      NaN      NaN         IT  48000.0
# 1   4      NaN      NaN         HR  52000.0
# 2   5      NaN      NaN         AC  50000.0
# 3   6      NaN      NaN        Dev  58000.0

# %%
pd.concat([df2,df3],axis=1)
# Out:
#    id employee    sal  id department  bonus
# 0   1   Akshay  60000   3         IT  48000
# 1   2  Swapnil  50000   4         HR  52000
# 2   3   Nikhil  55000   5         AC  50000
# 3   4   Sonali  40000   6        Dev  58000

# %%
df.aggregate(['sum','min','max','count','std'])
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# sum    11325.000000     876.500000    458.100000      563.80000    179.800000
# min        1.000000       4.300000      2.000000        1.00000      0.100000
# max      150.000000       7.900000      4.400000        6.90000      2.500000
# count    150.000000     150.000000    150.000000      150.00000    150.000000
# std       43.445368       0.828066      0.433594        1.76442      0.763161
#
#                                                   Target
# sum    Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# min                                          Iris-setosa
# max                                       Iris-virginica
# count                                                150
# std                                                  NaN

# %%
df.aggregate({
    'Id':['min','sum'],
    'SepalWidthCm':['max','count']
})
# Out:
#             Id  SepalWidthCm
# min        1.0           NaN
# sum    11325.0           NaN
# max        NaN           4.4
# count      NaN         150.0
